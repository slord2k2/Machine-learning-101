# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Assuming your data is stored in a pandas DataFrame called 'df'
object_cols = [col for col in df.columns if df[col].dtype == "object" and col not in ['EducationField', 'JobRole']]

# Perform label encoding on each column
for col in object_cols:
    label_encoder = LabelEncoder()
    df[col] = label_encoder.fit_transform(df[col])

# %%
pd.options.display.max_columns = 50
print(df)
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
ndf=df[['EducationField','JobRole']]
y=df[['Attrition']]
df=df.drop(['Attrition','EducationField','JobRole'],axis=1)
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import f_classif
# import pandas as pd

# # Assuming you have a DataFrame named "df" with features in columns "feature1", "feature2", etc.
# # and the target variable in a column "target"

# # Extract the features and target variable from the DataFrame

# # Apply standard scaling to the features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(df)

# # Instantiate SelectKBest with chi2 scoring function
# k = 30  # Number of top features to select
# selector = SelectKBest(f_classif, k=k)

# # Fit and transform the scaled features
# X_selected = selector.fit_transform(X_scaled, y)

# # Get the indices of the selected features
# selected_feature_indices = selector.get_support(indices=True)

# # Get the names of the selected features
# selected_feature_names = df.columns[selected_feature_indices]
# print(selected_feature_names)

# %%
# df=df[selected_feature_names]
# df
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
ndf_encoded = pd.get_dummies(ndf, columns=['EducationField', 'JobRole'])
merged_df = pd.merge(df, ndf_encoded, left_index=True, right_index=True)

# Print the merged DataFrame
print(merged_df)
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
merged_df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EducationField_Human Resources', 'EducationField_Life Sciences',
#        'EducationField_Marketing', 'EducationField_Medical',
#        'EducationField_Other', 'EducationField_Technical Degree',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
# ...

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df1=pd.DataFrame(df[['EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction']].mean(axis=1), columns=['Satisfaction'])
df2=pd.DataFrame(df[['EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction']].mean(axis=1), columns=['Salary'])
df3=pd.DataFrame(df[['YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion']].mean(axis=1), columns=['YearsAt'])
df = df.drop(['EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction','EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion'], axis=1)

# %%
df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EmployeeCount', 'EmployeeNumber', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsWithCurrManager'],
#       dtype='object')

# %%
merged_df.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EducationField_Human Resources', 'EducationField_Life Sciences',
#        'EducationField_Marketing', 'EducationField_Medical',
#        'EducationField_Other', 'EducationField_Technical Degree',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(merged_df,y,test_size=0.25,random_state=42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1102, 47), (368, 47), (1102, 1), (368, 1))

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Assuming you have X_train, X_test, y_train, y_test as your training and testing data

# Apply standard scaling to X_train, X_test, y_train, and y_test
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
y_train_scaled = scaler.fit_transform(y_train.values.reshape(-1, 1)).ravel()
y_test_scaled = scaler.transform(y_test.values.reshape(-1, 1)).ravel()

# Convert the scaled arrays back to DataFrames if needed
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
y_train_scaled = pd.Series(y_train_scaled, name='y_train_scaled')
y_test_scaled = pd.Series(y_test_scaled, name='y_test_scaled')

# Print the scaled DataFrames
print("X_train_scaled:\n", X_train_scaled)
print("X_test_scaled:\n", X_test_scaled)
print("y_train_scaled:\n", y_train_scaled)
print("y_test_scaled:\n", y_test_scaled)
# Out:
# X_train_scaled:
#             Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    -0.852159        0.588606  -0.508455   -0.502636         -0.285906
# 1    -0.093088        0.588606   0.209318    1.400816         -1.017204
# 2    -0.309965        0.588606   1.295810    1.400816         -0.773438
# 3    -1.069036        0.588606   0.381387    1.400816         -0.042139
# 4    -0.526843        0.588606   0.319933    1.400816          0.079744
# ...        ...             ...        ...         ...               ...
# 1097 -0.201527        0.588606  -0.120071   -0.502636          2.273640
# 1098  0.449105        0.588606  -0.864884   -0.502636         -0.529672
# 1099 -1.611229       -0.937615   1.123741   -0.502636         -0.773438
# 1100 -0.852159        0.588606   1.423632   -0.502636          0.445393
# 1101  1.425053        0.588606  -1.314721    1.400816         -0.042139
#
#       Education  EmployeeCount  EmployeeNumber    Gender  HourlyRate  \
# ...

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
random_state=42
cv=5
scoring='roc_auc'
verbose=2

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform

C_val = uniform(loc=0, scale=4)
lr=LogisticRegression(verbose=verbose,random_state=random_state,class_weight='balanced',max_iter=500,n_jobs=-1)
parameters={'C':C_val}
clf=RandomizedSearchCV(lr,parameters,verbose=verbose,cv=cv,random_state=random_state,scoring=scoring,n_iter=100,n_jobs=-1)
best_model=clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
from sklearn.metrics import roc_auc_score
y_pred=best_model.predict(X_test)
test_acc_lr=accuracy_score(y_test,y_pred)*100
auc_roc_lr = roc_auc_score(y_test,y_pred)
test_acc_lr,auc_roc_lr
# Out:
# (65.21739130434783, 0.640625)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=best_model.classes_)
disp.plot()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_jobs=-1)
from sklearn.model_selection import RandomizedSearchCV
k_range=np.arange(1,100,5)
param_grid=dict(n_neighbors=k_range)
grid=RandomizedSearchCV(knn,param_grid,cv=cv,random_state=random_state,scoring=scoring,verbose=verbose)
grid_serch=grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END .....................................n_neighbors=86; total time=   0.0s
# [CV] END .....................................n_neighbors=86; total time=   0.0s
# [CV] END .....................................n_neighbors=86; total time=   0.0s
# [CV] END .....................................n_neighbors=86; total time=   0.0s
# ...

# %%
grid_serch.best_params_
# Out:
# {'n_neighbors': 16}

# %%
y_pred=grid_serch.predict(X_test)
test_acc_knn=accuracy_score(y_test,y_pred)*100
auc_roc_knn = roc_auc_score(y_test,y_pred)
test_acc_knn,auc_roc_knn
# Out:
# (86.1413043478261, 0.4953125)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=grid_serch.classes_)
disp.plot()
plt.show()

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {"max_depth": [3, None],"max_features": randint(1, 9),"min_samples_leaf": randint(1, 9),"criterion": ["gini", "entropy"]}

# %%
tree = DecisionTreeClassifier()
clf=RandomizedSearchCV(tree, param_dist,verbose=verbose,cv=cv,random_state=random_state,scoring=scoring,n_iter=100,n_jobs=-1)
best_model=clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits

# %%
best_model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'max_features': 7,
#  'min_samples_leaf': 7}

# %%
y_pred=best_model.predict(X_test)
test_acc_dt=accuracy_score(y_test,y_pred)*100
auc_roc_dt = roc_auc_score(y_test,y_pred)
test_acc_dt,auc_roc_dt
# Out:
# (87.22826086956522, 0.5192708333333333)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=best_model.classes_)
disp.plot()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
param_grid = {
    'n_estimators': np.arange(10, 500, 10),
    'max_depth': np.arange(1, 20),
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}
rf = RandomForestClassifier(random_state=random_state, class_weight='balanced', n_jobs=-1)
clf = RandomizedSearchCV(rf, param_distributions=param_grid, n_iter=100, cv=cv, verbose=verbose, random_state=random_state, n_jobs=-1, scoring=scoring)
best_model = clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:910: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
best_model.best_params_
# Out:
# {'n_estimators': 260,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_depth': 19,
#  'bootstrap': True}

# %%
y_pred=best_model.predict(X_test)
test_acc_rf=accuracy_score(y_test,y_pred)*100
auc_roc_rf= roc_auc_score(y_test,y_pred)
test_acc_rf,auc_roc_rf
# Out:
# (86.95652173913044, 0.5442708333333334)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=best_model.classes_)
disp.plot()
plt.show()

# %%
from prettytable import PrettyTable
x = PrettyTable(['Model', 'Accuracy', 'ROC_AUC'])
x.add_row(['Logistic Regresstion', round(test_acc_lr,5), round(auc_roc_lr,5)])
x.add_row(['KNN', round(test_acc_knn,5), round(auc_roc_knn,5)])
x.add_row(['Decision Tree', round(test_acc_dt,5), round(auc_roc_dt,5)])
x.add_row(['Random Forest', round(test_acc_rf,5), round(auc_roc_rf,5)])
print(x)
# Out:
# +----------------------+----------+---------+
# |        Model         | Accuracy | ROC_AUC |
# +----------------------+----------+---------+
# | Logistic Regresstion | 65.21739 | 0.64062 |
# |         KNN          | 86.1413  | 0.49531 |
# |    Decision Tree     | 87.22826 | 0.51927 |
# |    Random Forest     | 86.95652 | 0.54427 |
# +----------------------+----------+---------+
