# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Secondhand Car price Prediction.csv")

# %%
X=df[['on road old', 'years', 'km', 'rating','condition', 'economy', 'hp', 'torque']]
y=df[ 'current price']

# %%
sns.pairplot(data=df,x_vars=['on road old', 'years', 'km', 'rating','condition', 'economy', 'hp', 'torque'],y_vars='current price',kind='reg')

# %%
sns.heatmap(X,cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# 389464.6224933441

# %%
reg.coef_
# Out:
# array([ 5.12929969e-01, -1.44905732e+03, -4.07417232e+00,  5.33825867e+02,
#         4.26940507e+03, -1.35040589e+02, -1.31674375e+01,  2.81624602e+01])

# %%
y_pred=reg.predict(X_test)

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 24996.843753580222

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 880097143.0863638

# %%
np.sqrt(metrics.mean_squared_error(y_test,y_pred) )
# Out:
# 29666.431249585174

# %%
reg.score(X_test,y_test )*100
# Out:
# 94.22935231365692

# %%
f"{reg.score(X_test,y_test )*100} %"
# Out:
# '94.22935231365692 %'
