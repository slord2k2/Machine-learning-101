# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('Canada.csv')
df.head()
# Out:
#    Year  Per Capita Income
# 0  1970               7775
# 1  1971               7241
# 2  1972               7913
# 3  1973               7857
# 4  1974               7412

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Year']],df['Per Capita Income'])
# Out:
# LinearRegression()

# %%
reg2=KNeighborsClassifier(n_neighbors=3)
reg2.fit(df[['Year']],df['Per Capita Income'])
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
reg2
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
reg
# Out:
# LinearRegression()

# %%
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.scatter(df.Year,df['Per Capita Income'],color='red',marker='+')
plt.plot(df.Year,reg.predict(df[['Year']]),color="blue")

# %%
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.scatter(df.Year,df['Per Capita Income'],color='red',marker='+')
plt.plot(df.Year,reg2.predict(df[['Year']]),color="blue")

# %%
d=pd.DataFrame(df.Year)
# d = d.reset_index(drop=True)
d.head
# Out:
# <bound method NDFrame.head of     Year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016>

# %%
d.to_csv('Canada.csv',index=False)
